# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data = data.dropna()

# %%
x = data.category
y = data.sub_category

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
plt.scatter(x, y)

# %%
plt.show()

# %%
keys = [k for k,v in data.category.value_counts().to_dict().items()]
keys
# Out:
# ['data',
#  'recharge cards',
#  'sms',
#  'bundle purchase',
#  'account status',
#  'easy credit',
#  'one money - pin resets',
#  'vas requests',
#  'registration',
#  'telemune vas',
#  'time request',
#  'bundle reversals',
#  'one money - registrations',
#  'calls',
#  'one money - transactions',
#  'network quality',
#  'replacements',
#  'promotions',
#  'one money - debit cards',
#  'whatsapp',
#  'one money - dealer issues',
#  'ussd',
#  'customer complaints',
#  'one money - zipit',
#  'promotional messages',
#  'one money - airtime purchases',
#  'existing products',
#  'khuluma 24 / 7',
#  'availability of simcards/airtime',
#  'ndebele',
#  'tarrifs',
#  'one money - know your customer',
#  'agent network',
#  'roaming',
#  'new products',
#  'mobile app',
#  'dealer',
#  'one money - zesa tokens',
#  'one fi',
#  'one money - tarrifs',
#  'one money - agent distribution network',
#  'one tech',
#  'vendor',
#  'mi fi',
#  'postpaid',
#  'khuluma 24/7']

# %%
the_data = data.loc[data.category == 'data']

# %%
the_data.sub_category.value_counts()
# Out:
# settings                                         5187
# depletion/usage                                  2369
# data depletion                                   1149
# out of bundle browsing                            866
# lte activation request                            274
# connectivity                                      216
# content bundles                                    66
# connectivity                                       52
# airtime balance                                    41
# connection                                         37
# airtime depletion                                  36
# usage                                              33
# airtime usage                                      26
# depletion                                          15
# fusion queries                                     14
# balance enquiry                                    13
# failing to connect                                 11
# ...
